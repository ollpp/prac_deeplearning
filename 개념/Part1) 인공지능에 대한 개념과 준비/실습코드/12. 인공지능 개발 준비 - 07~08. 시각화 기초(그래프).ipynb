# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline     # magic function : jupyrter 내부에 그림을 띄우겠다는 명령
# Out:
# UsageError: unrecognized arguments: # magic function : jupyrter 내부에 그림을 띄우겠다는 명령

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data = np.random.randn(50).cumsum()
data
# Out:
# array([-0.59365641, -0.67705455, -0.27993866, -0.15555542, -0.02721582,
#        -1.01665909, -1.85671566, -1.02497648,  0.47139836, -0.13122584,
#         0.76915495, -0.40121418,  0.47380559,  0.53555949,  1.89163311,
#         2.20395386,  0.75571982,  2.80455297,  4.00628251,  4.36747648,
#         4.38188911,  3.27518958,  2.23536194,  2.80753202,  1.40612145,
#         1.99675372,  1.72159213,  2.26183333,  2.71244866,  2.23300737,
#         1.81654284, -0.20542221,  2.05150822,  2.77351251,  2.6179888 ,
#         3.86869561,  3.5463601 ,  3.30062843,  4.2439758 ,  3.48187792,
#         2.40720289,  3.68963976,  3.59315019,  4.09510492,  4.37005403,
#         5.58718407,  4.85170312,  4.9874647 ,  6.0421137 ,  7.51846845])

# %%
plt.plot(data)
plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1,2,1)     # 1개의 행에 2개의 열을 가진 것중 1번째
plt.subplot(1,2,2)     # 1개의 행에 2개의 열을 가진 것중 2번째
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
plt.subplot(2,2,1)     # 첫번째 subplot
plt.plot(data)

plt.subplot(2,2,2)
plt.hist(hist_data, bins=20)

plt.subplot(2,2,3)
plt.scatter(scat_data, np.arange(30) + 3*np.random.randn(30))

# plot, hist, scatter에 따라 맞는 그래프가 넣어진다.

plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
plt.plot(data, 'yv')
plt.show()

# %%
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(10,5))     # figure의 속성값 firsize로 크기 조절
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(data)

plt.subplot(2, 2, 2)
plt.hist(data)

plt.subplot(2, 2, 3)
plt.scatter(scat_data, np.arange(30) + 3*np.random.randn(30))

plt.show()

# %% [markdown]
# - 비율 조절

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label = 'Default')
plt.plot(data, 'k-', drawstyle='steps-post')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Random Graph')   # 제목
plt.xlabel('Stages')        # x축
plt.ylabel('values')        # y축

plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.plot(np.random.randn(1000).cumsum(),'k',label='one')
plt.plot(np.random.randn(1000).cumsum(),'b',label='two')
plt.plot(np.random.randn(1000).cumsum(),'r',label='three')

plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig("fig_saved.svg")

# 그래프가 현재 작업환경 위치에 저장이 된다.
