# %% [markdown]
# ## package 불러오기

# %%
import numpy as np

from PIL import Image

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# ## 이미지 파일 열기

# %% [markdown]
# opencv로도 열수 있지만, shape 순서가 바뀔 때도 있어서 PIL로 여는 것을 개인적으로 선호

# %%
path = 'source/dog.jpg'

image_pil = Image.open(path)
image = np.array(image_pil)

# %% [markdown]
# ---

# %% [markdown]
# ## 이미지 들여다 보기

# %%
image.shape
# image는 2차원이지만 rgb때문에 3차원으로 나옴
# Out:
# (734, 1100, 3)

# %%
np.max(image), np.min(image)
# Out:
# (255, 0)

# %% [markdown]
# 이미지를 열기 전에 shape 및 min, max를 통해서 이미지의 range 확인 필요

# %% [markdown]
# ___

# %% [markdown]
# ## 그래프로 시각화 하기

# %%
plt.hist(image.ravel(), 256, [0, 256])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 그림 나타내기

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ---
# ## 이미지 흑백으로 열기

# %%
image_pil = Image.open(path).convert("L")
image_bw = np.array(image_pil)

# %%
image_bw.shape

# rge가 사라지고 흑백이 되었기 때문에 3차원에서 2차원으로 줄어들었다.
# Out:
# (734, 1100)

# %% [markdown]
# ---
# ## 흑백 이미지 열기

# %%
# 2개의 차원일 때는 gray scale로 열림
plt.imshow(image_bw, 'gray')
plt.show()

# %% [markdown]
# ---
# ### 다른 색상으로 cmap 표현하기

# %% [markdown]
# ### gray scale

# %%
image_bw.shape
# Out:
# (734, 1100)

# %%
plt.imshow(image_bw, 'gray')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### RdBu

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### jet

# %%
plt.imshow(image_bw, 'jet')
plt.show()

# %% [markdown]
# ---
# ## Colorbar 추가하기

# %%
plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# ## 이미지 설정

# %% [markdown]
# 이미지 보기 사이즈 조절

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

# %% [markdown]
# ---
# ## 이미지에 제목 추가

# %%
plt.title('Tiger')
plt.imshow(image)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 두번째 이미지 열기

# %%
cat_path='source/cat.jpg'

image_pil = Image.open(cat_path)
cat_image = np.array(image_pil)

# %% [markdown]
# ---
# ## 두번쨰 이미지를 첫번째 이미지 모양에 맞추기

# %%
cat_image.shape
# Out:
# (183, 275, 3)

# %%
image.shape, cat_image.shape

# 강아지의 차원과 고양이의 차원이 서로 다르다
# Out:
# ((734, 1100, 3), (183, 275, 3))

# %% [markdown]
# ---

# %% [markdown]
# ## 두번째 이미지 합치기 위한 준비

# %%
import cv2

# %%
dog_image = cv2.resize(image, (275,183))     # shape에서의 차원과 다르다
dog_image.shape
# Out:
# (183, 275, 3)

# %%
dog_image.shape, cat_image.shape
# Out:
# ((183, 275, 3), (183, 275, 3))

# %% [markdown]
# ---

# %% [markdown]
# ## Image 합치기

# %%
plt.imshow(dog_image, alpha=0.8)
plt.imshow(cat_image, alpha=0.5)

# alpha를 통한 이미지 투명화!

plt.show()

# %% [markdown]
# ---
# # Subplot

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)               # ,를 생략하고 써주어도 된다.
plt.imshow(dog_image)

plt.subplot(222)
plt.imshow(image_bw,'gray')

plt.subplot(223)
plt.imshow(cat_image)
plt.show()
